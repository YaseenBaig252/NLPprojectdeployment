# %%
from keras.applications.vgg16 import VGG16
model=VGG16()
# Out:
# ...
# 553476096/553467096 [==============================] - 5s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
from keras.preprocessing.image import load_img
from keras.applications.imagenet_utils import preprocess_input
import numpy as np

# %%
image = load_img('/content/drive/MyDrive/Colab Notebooks/download.jpg',target_size=(224,224))

# %%
image = np.array(image)

# %%
image = image.reshape(1,image.shape[0],image.shape[1],image.shape[2])

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
image = preprocess_input(image)

# %%
image
# Out:
# array([[[[-89.939    ,  54.221    ,  -2.6800003],
#          [-86.939    ,  54.221    ,  -1.6800003],
#          [-77.939    ,  55.221    ,   0.3199997],
#          ...,
#          [-65.939    , -26.779    , -43.68     ],
#          [-59.939003 , -30.779    , -48.68     ],
#          [-59.939003 , -30.779    , -48.68     ]],
#
#         [[-94.939    ,  53.221    ,  -1.6800003],
#          [-92.939    ,  52.221    ,  -1.6800003],
#          [-81.939    ,  53.221    ,   0.3199997],
#          ...,
#          [-46.939003 ,  -0.7789993, -22.68     ],
#          [-47.939003 , -11.778999 , -34.68     ],
#          [-47.939003 , -11.778999 , -34.68     ]],
#
#         [[-99.939    ,  51.221    ,  -2.6800003],
#          [-97.939    ,  50.221    ,  -2.6800003],
#          [-89.939    ,  50.221    ,  -1.6800003],
#          ...,
#          [-40.939003 ,  18.221    , -10.68     ],
#          [-35.939003 ,  15.221001 , -13.68     ],
#          [-35.939003 ,  15.221001 , -13.68     ]],
#
# ...

# %%
yaseen = model.predict(image)

# %%
yaseen
# Out:
# array([[6.67443203e-07, 1.42876866e-08, 2.89798430e-09, 7.39664952e-09,
#         2.82513621e-08, 4.02998124e-09, 2.25578178e-09, 4.98147892e-06,
#         3.49315087e-05, 1.54696309e-07, 1.10961924e-08, 6.46889902e-08,
#         5.26928829e-08, 4.17757526e-08, 3.37295910e-06, 1.57780832e-07,
#         6.43756763e-08, 7.33766547e-06, 4.08625201e-05, 2.12566196e-08,
#         2.20376009e-07, 1.33350838e-07, 2.06386872e-08, 4.38487878e-05,
#         3.51757762e-07, 1.85913741e-05, 2.23115967e-06, 2.17909943e-07,
#         7.30793981e-05, 4.04806769e-06, 5.93920231e-06, 8.33786203e-07,
#         2.08357005e-06, 3.52045539e-08, 4.18966829e-06, 2.78880452e-05,
#         7.77242803e-06, 5.09101073e-06, 2.61878256e-07, 4.30541841e-05,
#         1.38938006e-07, 1.55361931e-07, 3.05809237e-07, 1.69923666e-07,
#         6.77560251e-07, 1.16152773e-06, 4.50876405e-06, 1.07720120e-06,
#         2.55961572e-06, 9.19424224e-07, 2.92784921e-06, 1.60675427e-06,
# ...

# %%
from keras.applications.vgg16 import preprocess_input, decode_predictions
label = decode_predictions(yaseen)
label
# Out:
# [[('n02093256', 'Staffordshire_bullterrier', 0.53156716),
#   ('n02099712', 'Labrador_retriever', 0.25583556),
#   ('n02110958', 'pug', 0.03942987),
#   ('n04254680', 'soccer_ball', 0.03852485),
#   ('n02099267', 'flat-coated_retriever', 0.035849232)]]

# %%
import keras,os
from keras.models import sequential

# %%
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
trdata= ImageDataGenerator()
traindata= trdata.flow_from_directory(directory='/content/drive/MyDrive/Colab Notebooks/download.jpg',target_size=(224,224))
tsdata= ImageDataGenerator()
testdata= tsdata.flow_from_directory(directory= '/content/drive/MyDrive/Colab Notebooks/images.jpg',target_size=(224,224))
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-29-a22b3ca32601> in <module>()
#       1 trdata= ImageDataGenerator()
# ----> 2 traindata= trdata.flow_from_directory(directory='/content/drive/MyDrive/Colab Notebooks/download.jpg',target_size=(224,224))
#       3 tsdata= ImageDataGenerator()
#       4 testdata= tsdata.flow_from_directory(directory= '/content/drive/MyDrive/Colab Notebooks/images.jpg',target_size=(224,224))
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     969         follow_links=follow_links,
#     970         subset=subset,
# --> 971         interpolation=interpolation)
#     972
#     973   def flow_from_dataframe(self,
#
# ...
